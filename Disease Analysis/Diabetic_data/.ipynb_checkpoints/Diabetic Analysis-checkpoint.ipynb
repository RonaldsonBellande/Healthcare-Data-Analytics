# %% [markdown]
# # Diabetic Analysis with Machine Learning Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.svm import SVC

# %%
diabetic_data = pd.read_csv('diabetic_data.csv')
diabetic_data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
X_axis = diabetic_data.iloc[:,4].values
Y_axis = diabetic_data.iloc[:,49].values
print("Dimensions : {}".format(diabetic_data.shape))
# Out:
# Dimensions : (101766, 50)

# %%
diabetic_data.groupby('readmitted').size()
# Out:
# readmitted
# <30    11357
# >30    35545
# NO     54864
# dtype: int64

# %%
diabetic_data.groupby('readmitted').hist(figsize=(12,12))
# Out:
# readmitted
# <30    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# >30    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# NO     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# dtype: object

# %%
diabetic_data.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# ...

# %%
diabetic_data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
dataframe = pd.DataFrame(Y_axis)
Y_axis
# Out:
# array(['NO', '>30', 'NO', ..., 'NO', 'NO', 'NO'], dtype=object)

# %%
#Replasing everything that is >30 into NO
Y_axis = [sub.replace('>30', 'NO') for sub in Y_axis]

# %%
Y_axis
# Out:
# ['NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '<30',
#  '<30',
#  'NO',
#  'NO',
#  'NO',
#  '<30',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '<30',
#  'NO',
#  'NO',
#  'NO',
#  '<30',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '<30',
#  'NO',
#  '<30',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  '<30',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
# ...

# %%
#convert all features to numerical value
labelencoder_Y_axis = LabelEncoder()
Y_axis = labelencoder_Y_axis.fit_transform(Y_axis)

# %%
#Replace <30 with 1. Rest of the values are 0
where_0 = np.where(Y_axis == 0)
where_1 = np.where(Y_axis == 1)

Y_axis[where_0] = 1
Y_axis[where_1] = 0

# %%
#replacing age with numerical values
diabetic_data.groupby('age').size()
# Out:
# age
# [0-10)        161
# [10-20)       691
# [20-30)      1657
# [30-40)      3775
# [40-50)      9685
# [50-60)     17256
# [60-70)     22483
# [70-80)     26068
# [80-90)     17197
# [90-100)     2793
# dtype: int64

# %%
diabetic_data.groupby('age').hist(figsize=(12,12))
# Out:
# age
# [0-10)      [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [10-20)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [20-30)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [30-40)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [40-50)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [50-60)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [60-70)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [70-80)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [80-90)     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# [90-100)    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# dtype: object

# %%
#dataframe = pd.DataFrame(X_axis)
dataframe = pd.DataFrame(X_axis)
X_axis
where_0 = np.where(X_axis == '[0-10)')
where_1 = np.where(X_axis == '[10-20)')
where_2 = np.where(X_axis == '[20-30)')
where_3 = np.where(X_axis == '[30-40)')
where_4 = np.where(X_axis == '[40-50)')
where_5 = np.where(X_axis == '[50-60)')
where_6 = np.where(X_axis == '[60-70)')
where_7 = np.where(X_axis == '[70-80)')
where_8 = np.where(X_axis == '[80-90)')
where_9 = np.where(X_axis == '[90-100)')


X_axis[where_0] = 1
X_axis[where_1] = 2
X_axis[where_2] = 3
X_axis[where_3] = 4
X_axis[where_4] = 5
X_axis[where_5] = 6
X_axis[where_6] = 7
X_axis[where_7] = 8
X_axis[where_8] = 9
X_axis[where_9] = 10

# %%
print(X_axis)
print(Y_axis)
# Spliting the dataset into the Training set and the Test set
X_train, X_test, Y_train, Y_test = train_test_split(X_axis, Y_axis, test_size = 0.20, random_state = 0)
# Out:
# [1 2 3 ... 8 9 8]
# [0 0 0 ... 0 0 0]

# %%
#convert all features to numerical value
labelencoder_X_axis = LabelEncoder()
X_axis = labelencoder_X_axis.fit_transform(X_axis)

# %%
#Feature Scaling
standard_scaler = StandardScaler()
#Split it so you can train and test from diffrent sets
X_train = X_train.reshape(1, -1)
X_test = X_test.reshape(1, -1)
X_train = standard_scaler.fit_transform(X_train)
X_test = standard_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-1c43c55e4bea> in <module>
#       5 X_test = X_test.reshape(1, -1)
#       6 X_train = standard_scaler.fit_transform(X_train)
# ----> 7 X_test = standard_scaler.transform(X_test)
#
# ~/.local/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     789
#     790         copy = copy if copy is not None else self.copy
# --> 791         X = self._validate_data(X, reset=False,
#     792                                 accept_sparse='csr', copy=copy,
#     793                                 estimator=self, dtype=FLOAT_DTYPES,
#
# ~/.local/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     434
#     435         if check_params.get('ensure_2d', True):
# --> 436             self._check_n_features(X, reset=reset)
# ...

# %%
#Fitting the logistic Regression Algorithm to the Training set
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, Y_train)

# %%
#Predicte the test set results
Y_pred = classifier.predict(X_test)

# %%
#Create the confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
print("Accuracy of Logistic Regression:", accuracy_score(Y_test, Y_pred))

# %%
print("Precision of Logistic Regression:", precision_score(Y_test, Y_pred, average='weighted'))

# %%
#Fitting the Support Vector Machines Algorithm to the Training set
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, Y_train)

# %%
#Predict the test result
Y_pred = classifier.predict(X_test)

# %%
#Create a confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
print("Accuracy of SVC:", accuracy_score(Y_test, Y_pred))

# %%
print("Precision of SVC:", precision_score(Y_test, Y_pred, average='weighted'))
